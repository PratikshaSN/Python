# %% [markdown]
# <a href="https://colab.research.google.com/github/PratikshaSN/Python/blob/main/ExpenseTracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Course-End Project: Personal Expense Tracker

import os

expenses=[]
def add_expense_details() :
    expense={}
    print("\n************* Add Expense ************\n")
    print("Please enter below details for expense tracking")
    expense_date=input        ("Date (YYYY-MM-DD)             : ")
    expense_category=input    ("Category: (Food/Travel/Books) : ")
    expense_description=input ("Description                   : ")
    expense_amount=float(input("Amount spent                  : "))
    print("\n*********** Added Expense Done.************\n")
    expense['date']=expense_date
    expense['category']=expense_category
    expense['amount']=expense_amount
    expense['description']=expense_description
    expenses.append(expense)

def expenses_information_store():
    print("\n************ Storing Expenses *************\n")
    expenses_file = 'expenses.csv'
    with open(expenses_file, "w+") as f:
        for expense in expenses:
            f.write("{},{},{},{}\n".format(expense['date'],expense['category'],expense['amount'],expense['description']))

def expenses_information_view():
    print("\n************ Expenses View *************\n")

    if not expenses:
        print("No expenses stored.. you need to add first")
        return

    print("Date\t\tCategory\tAmount\tDescription")
    for expense in expenses:
            if not (expense['date'] or expense['category'] or expense['amount'] or expense['description']):
                print("Incomplete information.. skipping")
                return

            print(f"{expense['date']:<10}\t{expense['category']:<10}\t{expense['amount']:>10}\t{expense['description']}")

def expenses_information_load():
    expenses_file = 'expenses.csv'
    if os.path.exists(expenses_file):
        mode='r'
    else:
        return
    with open(expenses_file, mode) as f:
        expenses_readline=f.read()

    for r in expenses_readline.splitlines():
            r_date,r_category,r_amount,r_description=r.strip().split(',')
            expens1={}
            expens1['date'],expens1['category'],expens1['description'],expens1['amount']=r_date,r_category,r_description,float(r_amount)
            expenses.append(expens1)

def expenses_budget_track():
    total_expenses=0
    print("\n************* Budget Tracker **************\n")
    budget=float(input("Enter total monthly budget: "))
    for expense in expenses:
        total_expenses+=expense['amount']

    total=budget-total_expenses
    if (total<=0):
        print(f"Warning: you have exceeded the budget of this month: {total}")
    else:
        print(f"You are within budget of this month, total balance : {total}")

## main
expenses_information_load()

while True:
    print("\*********** Personal Expense Tracker ************\n")
    print("1.. Add   Expense\n2.. View  Expenses\n3.. Track Budget\n4.. Save Expenses\n5.. Exit\n\n")
    choice=int(input("Enter your choice: "))

    if choice==1:
        user_expense=add_expense_details()
    elif choice==2:
        expenses_information_view()
    elif choice==3:
        expenses_budget_track()
    elif choice==4:
        expenses_information_store()
    elif choice==5:
        print("\nExiting.. the program..\n\n")
        break
    else:
        print("Invalid choice..")

## Done.
# Out:
# \*********** Personal Expense Tracker ************
#
# 1.. Add   Expense
# 2.. View  Expenses
# 3.. Track Budget
# 4.. Save Expenses
# 5.. Exit
#
#
# Enter your choice: 2
#
# ************ Expenses View *************
#
# No expenses stored.. you need to add first
# \*********** Personal Expense Tracker ************
#
# 1.. Add   Expense
# 2.. View  Expenses
# 3.. Track Budget
# 4.. Save Expenses
# 5.. Exit
#
#
# Enter your choice: 1
#
# ************* Add Expense ************
#
# Please enter below details for expense tracking
# Date (YYYY-MM-DD)             : 2025-01-11
# Category: (Food/Travel/Books) : Food
# Description                   : lunch
# Amount spent                  : 2000
#
# *********** Added Expense Done.************
#
# \*********** Personal Expense Tracker ************
#
# 1.. Add   Expense
# 2.. View  Expenses
# 3.. Track Budget
# 4.. Save Expenses
# 5.. Exit
#
#
# Enter your choice: 4
#
# ************ Storing Expenses *************
#
# ...
